# %% [markdown]
# <a href="https://colab.research.google.com/github/HussainAhmed202/Computer-Engineering_Bachelors-Maths/blob/master/01-calculus-python/src/00_Intro_to_Numerical_Math_with_sympy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# check if sympy installed
# !pip show sympy

# if not installed, install it
# !pip install sympy
